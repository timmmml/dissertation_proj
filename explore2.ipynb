# %%
import pickle
from utils.path_settings import *

# %%
model_paths = [
    "GRU_1layer_8hidden_0.1q_model_gradual_constant",
    "GRU_1layer_16hidden_0.1q_model_gradual_constant",
    "GRU_1layer_32hidden_0.1q_model_gradual_constant",
    "FC_16_GRU_1layer_8hidden_0.1q_model_gradual_constant",
    "FC_16_GRU_1layer_16hidden_0.1q_model_gradual_constant",
    "FC_16_GRU_1layer_32hidden_0.1q_model_gradual_constant",
    "FC_32_GRU_1layer_8hidden_0.1q_model_gradual_constant",
    "FC_32_GRU_1layer_16hidden_0.1q_model_gradual_constant",
    "FC_32_GRU_1layer_32hidden_0.1q_model_gradual_constant",
    "ConvNeXt_Tiny_FC_16_GRU_8_A1_5x6x5_centered_1.1_res64_model_gradual",
    "ConvNeXt_Tiny_FC_16_GRU_8_A1_5x6x5_centered_1.1_res128_model_gradual",
    "ConvNeXt_Tiny_FC_16_GRU_8_A1_5x6x5_centered_1.1_res256_model_gradual",
    "ConvNeXt_Tiny_FC_16_GRU_8_cow_1.1_res64_model_gradual",
    "ConvNeXt_Tiny_FC_16_GRU_8_cow_1.1_res128_model_gradual",
    "ConvNeXt_Tiny_FC_16_GRU_8_cow_1.1_res256_model_gradual",
]
def plot_interactive(index, model_path_list, version = "Ground_Truth"):
    model_path = MODEL_SAVE_PATH + f"\\{model_path_list[index]}\\best_model_tuning_curves_{version}.pkl"
    fig = pickle.load(open(model_path, "rb"))
    fig.show()

# %%
plot_interactive(14, model_paths, "mgplvm")
# Out:
# <div>                            <div id="85405c70-a5c8-4b44-98a4-ae43731c9e8d" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85405c70-a5c8-4b44-98a4-ae43731c9e8d")) {                    Plotly.newPlot(                        "85405c70-a5c8-4b44-98a4-ae43731c9e8d",                        [{"marker":{"color":[-0.10989953306689688,-0.11529100627612797,-0.07656647052712216,0.0006384442839225263,-0.07823872429396449,-0.010632686279560263,-0.018532695232145617,-0.07578268070523028,-0.10586657922616113,-0.06362096048179493,-0.08092046558360076,-0.027908578943162808,-0.14395095990251577,-0.0773152618738195,-0.05748063367825748,-0.0518749361219219,-0.0898607271318339,-0.006942512525336349,-0.17267819925644237,0.012596334669070453,0.10084499873509352,-0.0
# ...

# %%
import numpy as np
import plotly.graph_objects as go

fig = go.Figure()
for i in range(n_size):
    n = i
    fig.add_trace(go.Scatter3d(
        x=xs[:, 0],
        y=xs[:, 1],
        z=xs[:, 2],
        mode='markers',
        marker=dict(
            size=4,
            reversescale=True,
            color=mean[n, :],
            opacity=0.5,
            colorbar=dict(
                title='Mean Value',
                tickvals=[mean[n, :].min(), 0, mean[n, :].max()],
                ticktext=[f"Low: {min(mean[n, :]):.3g}", f"Medium: {0}", f"High: {max(mean[n, :]):.3g}"],
            ),
            colorbar_title='Mean Value',
            colorscale="rdbu"
        ),
        name=f'Tuning Curve {i + 1}',
        showlegend=False,
        visible=False,
    ))

fig.update_layout(
    height=800,  
    width=800,  
    title='Tuning Curves',
    legend=dict(
        title='Tuning Curves',
        x=0.7,
        y=1.2
    ),
    scene=dict(
        xaxis=dict(title='X Axis'),
        yaxis=dict(title='Y Axis'),
        zaxis=dict(title='Z Axis')
    ),
    scene2=dict(
        xaxis=dict(title='X Axis'),
        yaxis=dict(title='Y Axis'),
        zaxis=dict(title='Z Axis')
    ),
    scene3=dict(
        xaxis=dict(title='X Axis'),
        yaxis=dict(title='Y Axis'),
        zaxis=dict(title='Z Axis')
    ),
    scene4=dict(
        xaxis=dict(title='X Axis'),
        yaxis=dict(title='Y Axis'),
        zaxis=dict(title='Z Axis')
    ),
    scene5=dict(
        xaxis=dict(title='X Axis'),
        yaxis=dict(title='Y Axis'),
        zaxis=dict(title='Z Axis')
    ),
    scene6=dict(
        xaxis=dict(title='X Axis'),
        yaxis=dict(title='Y Axis'),
        zaxis=dict(title='Z Axis')
    ),
    scene7=dict(
        xaxis=dict(title='X Axis'),
        yaxis=dict(title='Y Axis'),
        zaxis=dict(title='Z Axis')
    )
)
fig.data[0].visible = True

updatemenus = [
    dict(
        type="buttons",
        showactive=False,
        buttons=[
            dict(label=f'Tuning Curve {i + 1}',
                 method='update',
                 args=[{'visible': [j == i for j in range(8)]}])
            for i in range(8)
        ],
    )
]

fig.update_layout(
    updatemenus=updatemenus,
    height=800, 
    width=800, 
    title='Tuning Curves',
    legend=dict(
        title='Tuning Curves',
        x=0.7,
        y=1.2
    ),
    scene=dict(
        xaxis=dict(title='X Axis'),
        yaxis=dict(title='Y Axis'),
        zaxis=dict(title='Z Axis')
    )
)
pickle.dump(fig, open(configs['save_path'] + "\\best_model_tuning_curves_Ground_Truth.pkl", "wb"))
if show: 
    fig.show()
