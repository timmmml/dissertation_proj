# %% [markdown]
# # Review Master
#
# This notebook helps with visualising key results and observations from the explorations in the mental rotations project.
#
# Timeline:
#
# 1. quaternions to angular velocities (preview work for me getting used to metrics used in the project)
#     training: batched_training.ipynb
#     analysis: mGPLVM_analyses.ipynb
#
# 2. spinned cow pics to angular velocities
#     training: imported_CNN_experimentations.ipynb
# 3. VAE spinned cow pics to angular velocities
#     training: VAE_experimentation.ipynb
#     (I think I actually didn't implement the to angular velocities part?)
# 4. Predictor-controller network (to control an ISN network)
#     exploration and training(
#         cow mesh PCA analysis
#         cube predictor and controller(
#             directly set dynamics vs.
#             control dynamics via inputs
#         )
#     ): explore_network.ipynb
#     analysis (performance): representation_analysis.ipynb
#     analysis (reps: RSA, PCA)
