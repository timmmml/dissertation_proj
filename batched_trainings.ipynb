# %%
# %load_ext autoreload
# %autoreload 2
from utils import goto_project_root
from utils.path_settings import MODEL_SAVE_PATH, DATA_PATH, LOG_PATH, CONFIG_PATH, FIG_PATH
from torch.utils.tensorboard import SummaryWriter
import SimulateDatasets.GenTrainingData as g
from utils import create_splits, get_dataloaders, force_remove_dir
from Network_models import Trainer as t
from importlib import reload
import os
reload(t)
reload(g)
import time
import torch
import numpy as np
from pytorch3d.transforms import so3_relative_angle
from pytorch3d.transforms import quaternion_to_matrix
import json
import Train_task.train_from_config_names as train
import SimulateDatasets.PretrainGenerator as p
import matplotlib.pyplot as plt
reload(train)
# Out:
# <module 'Train_task.train_from_config_names' from 'C:\\Users\\timmy\\Documents\\Projects_dir\\Mental_Rotations\\mental-rotations\\Train_task\\train_from_config_names.py'>

# %%
task = "0.1q"
network_name_epochs = {
    # "GRU_1layer_8hidden": 500,
    # "GRU_1layer_16hidden": 500,
    # "GRU_1layer_32hidden": 500,
    "FC_16_GRU_1layer_8hidden": 500,
    # "FC_32_GRU_1layer_8hidden": 500,
    # "FC_16_GRU_1layer_16hidden": 500,
    # "FC_32_GRU_1layer_16hidden": 500,
    # "FC_16_GRU_1layer_32hidden": 500,
    # "FC_32_GRU_1layer_32hidden": 500,
}
# additional_name = "silence_suppressed"
additionl_name = None
network_name_epochs_new = {}
for name, epochs in network_name_epochs.items():
    if additionl_name is not None:
        network_name_epochs_new[name + "_" + additional_name] = epochs
    else: 
        network_name_epochs_new[name] = epochs
special_names = "constant_rework_output_noise"
network_best_splits = train.train_from_config_names(network_name_epochs_new, task, 1, special_names, "train", add_noise = 
"output", noise_strength=0.01, infinite_data=True, inits = 1, additional_config={"epochs_to_calculate":20})
# Out:
# Using a scheduler
# Training FC_16_GRU_1layer_8hidden on task 0.1q, saving to D:\Projects\mental-rotations\models\FC_16_GRU_1layer_8hidden_0.1q_model_gradual_constant_rework_output_noise; copy the below for logs
# tensorboard --logdir=D:\Projects\mental-rotations\logs\FC_16_GRU_1layer_8hidden_0.1q_model_gradual_constant_rework_output_noise
# Training split 1
# Directory does not exist: D:\Projects\mental-rotations\logs\FC_16_GRU_1layer_8hidden_0.1q_model_gradual_constant_rework_output_noise\split_1
# Epoch 0, learning rate: 0.01
# Replaced 51.90514373779297% of the data, new data size: 128, original size: 128
# Replaced 88.37810516357422% of the data, new data size: 128, original size: 128
# Replaced 57.789947509765625% of the data, new data size: 128, original size: 128
# Replaced 55.87041473388672% of the data, new data size: 128, original size: 128
# Replaced 59.188819885253906% of the data, new data size: 128, original size: 128
# Epoch 100, learning rate: 0.01
# Replaced 73.12580108642578% of the data, new data size: 128, original size: 128
# Replaced 80.53257751464844% of the data, new data size: 128, original size: 128
# Epoch 200, learning rate: 0.01
# Replaced 84.11302185058594% of the data, new data size: 128, original size: 128
# Replaced 79.05870819091797% of the data, new data size: 128, original size: 128
# Replaced 68.59815216064453% of the data, new data size: 128, original size: 128
# Replaced 74.51201629638672% of the data, new data size: 128, original size: 128
# Replaced 76.94309997558594% of the data, new data size: 128, original size: 128
# Replaced 74.66502380371094% of the data, new data size: 128, original size: 128
# Epoch 300, learning rate: 0.001
# Replaced 85.68229675292969% of the data, new data size: 128, original size: 128
# Replaced 70.87714385986328% of the data, new data size: 128, original size: 128
# Replaced 83.75152587890625% of the data, new data size: 128, original size: 128
# Replaced 60.1356086730957% of the data, new data size: 128, original size: 128
# Epoch 400, learning rate: 0.001
# Replaced 84.4876480102539% of the data, new data size: 128, original size: 128
# Replaced 85.53936767578125% of the data, new data size: 128, original size: 128
# Replaced 52.23891830444336% of the data, new data size: 128, original size: 128
# Training FC_16_GRU_1layer_8hidden on task 0.1q complete. Saving best model to D:\Projects\mental-rotations\models\FC_16_GRU_1layer_8hidden_0.1q_model_gradual_constant_rework_output_noise; latest checkpoint to 499.
# Best split for FC_16_GRU_1layer_8hidden on task 0.1q is 1.

# %%
trainer =t.Trainer(train.build_config("GRU_1layer_8hidden", "0.1q", 1, 1, 
                                            special_names="constant_rework_output_noise_experiment"))
trainer.load_model(MODEL_SAVE_PATH + "\\GRU_1layer_8hidden_0"
                                     ".1q_model_gradual_constant_rework_output_noise_experiment\\split_1.pth", full 
= True)
trainer.save_model(MODEL_SAVE_PATH + "\\GRU_1layer_8hidden_0"
                                     ".1q_model_gradual_constant_rework_output_noise_experiment\\best_model.pth", 
             full = 
True)
# Out:
# Successfully removed directory: D:\Projects\mental-rotations\models\GRU_1layer_8hidden_0.1q_model_gradual_constant_rework_output_noise_experiment
# Successfully removed directory: D:\Projects\mental-rotations\logs\GRU_1layer_8hidden_0.1q_model_gradual_constant_rework_output_noise_experiment
# Successfully removed directory: D:\Projects\mental-rotations\models\GRU_1layer_8hidden_model_checkpoints_gradual_constant_rework_output_noise_experiment
# Using a scheduler
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[51], line 3
#       1 trainer =t.Trainer(train.build_config("GRU_1layer_8hidden", "0.1q", 1, 1,
#       2                                             special_names="constant_rework_output_noise_experiment"))
# ----> 3 trainer.load_model(MODEL_SAVE_PATH + "\\GRU_1layer_8hidden_0"
#       4                                      ".1q_model_gradual_constant_rework_output_noise_experiment\\split_1.pth", full
#       5 = True)
#       6 trainer.save_model(MODEL_SAVE_PATH + "\\GRU_1layer_8hidden_0"
#       7                                      ".1q_model_gradual_constant_rework_output_noise_experiment\\best_model.pth",
#       8              full =
#       9 True)
#
# File ~\Documents\Projects_dir\Mental_Rotations\mental-rotations\Network_models\Trainer.py:341, in Trainer.load_model(self, path, full)
#     339 def load_model(self, path, full=False):
#     340     if full:
# --> 341         self.model = torch.load(path)
#     342     else:
#     343         self.model.load_state_dict(torch.load(path))
#
# File ~\anaconda3\envs\mental-rotations\lib\site-packages\torch\serialization.py:997, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     994 if 'encoding' not in pickle_load_args.keys():
#     995     pickle_load_args['encoding'] = 'utf-8'
# --> 997 with _open_file_like(f, 'rb') as opened_file:
#     998     if _is_zipfile(opened_file):
#     999         # The zipfile reader is going to advance the current file position.
#    1000         # If we want to actually tail call to torch.jit.load, we need to
#    1001         # reset back to the original position.
#    1002         orig_position = opened_file.tell()
#
# File ~\anaconda3\envs\mental-rotations\lib\site-packages\torch\serialization.py:444, in _open_file_like(name_or_buffer, mode)
#     442 def _open_file_like(name_or_buffer, mode):
#     443     if _is_path(name_or_buffer):
# --> 444         return _open_file(name_or_buffer, mode)
#     445     else:
#     446         if 'w' in mode:
#
# File ~\anaconda3\envs\mental-rotations\lib\site-packages\torch\serialization.py:425, in _open_file.__init__(self, name, mode)
#     424 def __init__(self, name, mode):
# --> 425     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Projects\\mental-rotations\\models\\GRU_1layer_8hidden_0.1q_model_gradual_constant_rework_output_noise_experiment\\split_1.pth'

# %%
gen = p.PretrainGenerator(train.build_config("GRU_1layer_8hidden", "0.1q", 1, 1, 
                                            special_names="constant_rework_output_noise_experiment")['training_config'])
train_loader, val_loader = gen.generate(128, 32, True)
# Out:
# Successfully removed directory: D:\Projects\mental-rotations\models\GRU_1layer_8hidden_0.1q_model_gradual_constant_rework_output_noise_experiment
# Successfully removed directory: D:\Projects\mental-rotations\logs\GRU_1layer_8hidden_0.1q_model_gradual_constant_rework_output_noise_experiment
# Successfully removed directory: D:\Projects\mental-rotations\models\GRU_1layer_8hidden_model_checkpoints_gradual_constant_rework_output_noise_experiment

# %%
task = "0.1q"
for network_name, (split, e) in network_best_splits.items():
    epochs = 500
    config = train.build_config(network_name, task, 0, 1, special_names=special_names)
    config['optimizer_specs']['optimizer_params']["lr"] = 0.01
    trainer = t.Trainer(config)
    trainer.load_checkpoint(config['check_path'] + f"\\split_{split}\\checkpoint{e}.pth")
    # trainer.load_checkpoint(config['check_path'] + f"\\continue_training\\checkpoint499.pth")
    # trainer.scheduler = None
    data_path = config['training_config']['data_save_path'][:-4] +"_train2.pth" if (
        config)['training_config']['data_save_path'][-4:] == ".pth" else config['training_config']['data_save_path'] + "_train2.pth"
    data = torch.load(data_path)
    data.labels += torch.randn_like(data.labels) * 0.05
    import utils as u
    reload(u)
    dataloaders = u.get_dataloaders(data, config['training_config']['mini_batch_size'], 1)
    print("Continue training the best model")
    sub_log_path = config['log_path'] + "\\continue_training"
    sub_check_path = config['check_path'] + "\\continue_training"
    force_remove_dir(sub_log_path)
    force_remove_dir(sub_check_path)
    os.makedirs(sub_log_path, exist_ok=True)
    os.makedirs(sub_check_path, exist_ok=True)
    trainer.train(
        dataloaders[0][0],
        dataloaders[0][1],
        epochs=epochs,
        save_path = config['save_path'] + "\\continue_training.pth",
        check_path=sub_check_path,
        log_path = sub_log_path,
    )
    trainer.save_model(config['save_path'] + "\\continue_training.pth", full = 1)
    trainer.load_best_model()
    trainer.save_model(config['save_path'] + "\\best_model.pth", full = 1)
# Out:
# Path already exists for GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Continue training the best model
# Directory does not exist: D:\Projects\mental-rotations\logs\GRU_1layer_8hidden_silence_suppressed_0.1q_model_gradual_constant_rework_output_noise\continue_training
# Directory does not exist: D:\Projects\mental-rotations\models\GRU_1layer_8hidden_silence_suppressed_model_checkpoints_gradual_constant_rework_output_noise\continue_training
# Path already exists for GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Continue training the best model
# Directory does not exist: D:\Projects\mental-rotations\logs\GRU_1layer_16hidden_silence_suppressed_0.1q_model_gradual_constant_rework_output_noise\continue_training
# Directory does not exist: D:\Projects\mental-rotations\models\GRU_1layer_16hidden_silence_suppressed_model_checkpoints_gradual_constant_rework_output_noise\continue_training
# Path already exists for GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Continue training the best model
# Directory does not exist: D:\Projects\mental-rotations\logs\GRU_1layer_32hidden_silence_suppressed_0.1q_model_gradual_constant_rework_output_noise\continue_training
# Directory does not exist: D:\Projects\mental-rotations\models\GRU_1layer_32hidden_silence_suppressed_model_checkpoints_gradual_constant_rework_output_noise\continue_training
# Early stopping
# Path already exists for FC_16_GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Continue training the best model
# Directory does not exist: D:\Projects\mental-rotations\logs\FC_16_GRU_1layer_8hidden_silence_suppressed_0.1q_model_gradual_constant_rework_output_noise\continue_training
# Directory does not exist: D:\Projects\mental-rotations\models\FC_16_GRU_1layer_8hidden_silence_suppressed_model_checkpoints_gradual_constant_rework_output_noise\continue_training
# Path already exists for FC_32_GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_32_GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_32_GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Continue training the best model
# Directory does not exist: D:\Projects\mental-rotations\logs\FC_32_GRU_1layer_8hidden_silence_suppressed_0.1q_model_gradual_constant_rework_output_noise\continue_training
# Directory does not exist: D:\Projects\mental-rotations\models\FC_32_GRU_1layer_8hidden_silence_suppressed_model_checkpoints_gradual_constant_rework_output_noise\continue_training
# Early stopping
# Path already exists for FC_16_GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Continue training the best model
# Directory does not exist: D:\Projects\mental-rotations\logs\FC_16_GRU_1layer_16hidden_silence_suppressed_0.1q_model_gradual_constant_rework_output_noise\continue_training
# Directory does not exist: D:\Projects\mental-rotations\models\FC_16_GRU_1layer_16hidden_silence_suppressed_model_checkpoints_gradual_constant_rework_output_noise\continue_training
# Early stopping
# Path already exists for FC_32_GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_32_GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_32_GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Continue training the best model
# Directory does not exist: D:\Projects\mental-rotations\logs\FC_32_GRU_1layer_16hidden_silence_suppressed_0.1q_model_gradual_constant_rework_output_noise\continue_training
# Directory does not exist: D:\Projects\mental-rotations\models\FC_32_GRU_1layer_16hidden_silence_suppressed_model_checkpoints_gradual_constant_rework_output_noise\continue_training
# Early stopping
# Path already exists for FC_16_GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Continue training the best model
# Directory does not exist: D:\Projects\mental-rotations\logs\FC_16_GRU_1layer_32hidden_silence_suppressed_0.1q_model_gradual_constant_rework_output_noise\continue_training
# Directory does not exist: D:\Projects\mental-rotations\models\FC_16_GRU_1layer_32hidden_silence_suppressed_model_checkpoints_gradual_constant_rework_output_noise\continue_training
# Early stopping
# Path already exists for FC_32_GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_32_GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_32_GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Continue training the best model
# Directory does not exist: D:\Projects\mental-rotations\logs\FC_32_GRU_1layer_32hidden_silence_suppressed_0.1q_model_gradual_constant_rework_output_noise\continue_training
# Directory does not exist: D:\Projects\mental-rotations\models\FC_32_GRU_1layer_32hidden_silence_suppressed_model_checkpoints_gradual_constant_rework_output_noise\continue_training
# Early stopping

# %%
from Plots.network_analysis_plots import network_analysis_plots_pretrain as nplot
names_list = [
    "GRU_1layer_8hidden",
    "GRU_1layer_16hidden",
    "GRU_1layer_32hidden",
    "FC_16_GRU_1layer_8hidden",
    "FC_32_GRU_1layer_8hidden",
    "FC_16_GRU_1layer_16hidden",
    "FC_32_GRU_1layer_16hidden",
    "FC_16_GRU_1layer_32hidden",
    "FC_32_GRU_1layer_32hidden"
]
names_list_new = [name + "_silence_suppressed" for name in names_list]
test = nplot(names_list_new,
    task = "0.1q", 
    output_dir = FIG_PATH + "\\summary\\pretrain_summary_noisy_silence_suppressed_new.png", 
    special_name= "constant_rework_output_noise", 
    test_data_path = DATA_PATH + f"\\Data_{task}_test.pth")
# Out:
# Path already exists for GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Path already exists for GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Path already exists for GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Path already exists for FC_16_GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Path already exists for FC_32_GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_32_GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_32_GRU_1layer_8hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Path already exists for FC_16_GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Path already exists for FC_32_GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_32_GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_32_GRU_1layer_16hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Path already exists for FC_16_GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Path already exists for FC_32_GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_32_GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Path already exists for FC_32_GRU_1layer_32hidden_silence_suppressed in task 0.1q. Assume the model is already trained.
# Using a scheduler

# %% [markdown]
# # Plotting activity traces

# %%
names_list = ['FC_16_GRU_1layer_8hidden']
special_names = "constant_rework_output_noise"
num = 1
features = torch.zeros(num, 100, 8).to("cuda")
target = torch.zeros(num, 4).to("cuda")

for i in range(num):
    target[i] = torch.tensor([0.1826, -0.3651, -0.5477, -0.7303]).to("cuda")
    target[i] = torch.tensor([0.1826, 0.3651, 0.5477, 0.7303]).to("cuda")
    target[i] = target[i] / torch.norm(target[i])
    for j in range(50):
        features[i, j, :] = torch.cat([target[i], -target[i]])
        
# features += torch.randn_like(features) * 0.1
for network_name in names_list: 
    config = train.build_config(network_name, task, 0, 1, special_names=special_names)
    rnn_trainer = t.Trainer(config)
    rnn_trainer.load_model(config["save_path"] + "\\best_model.pth", full=True)
    rnn_trainer.model.eval()
    # Let's print an average of geodesic distances between network output and target, for a batch of 1000 random quaternions 
    # where all parts are positive. 

    rnn_trainer.model(features)
    pred = rnn_trainer.model.pred
    g_loss = rnn_trainer.distance_loss(pred, target)
    print(f"Average geodesic distance: {g_loss[0].mean()}")
    model = rnn_trainer.model


    def get_hidden_state(module, input, output):
        global hidden_states
        hidden_states.append(output[0].detach().clone())


    model.rnn.register_forward_hook(get_hidden_state)
    hidden_states = []
    out = model(features)
    activations = hidden_states[0][0:, :]  # Get the single tensor from the list
    activations = activations.view(-1, activations.shape[-1])  # Flatten to (batch_size * seq_len, hidden_unit_num)
    activations = activations.cpu().detach().numpy()

    time = np.arange(100)
    fig, ax = plt.subplots()
    for neuron in range(model.hidden_size):
        ax.plot(time, activations[:, neuron], label=f"Neuron {neuron}")
    ax.legend()
    ax.set_xlabel('t')
    ax.set_ylabel('Activation')
    ax.set_title('Neuron Activations (GRU(8))')
    # fig.savefig(FIG_PATH + "\\neuron_activations\\" + f"{network_name}_hidden_activations.png")
    fig, ax = plt.subplots()
    time = np.arange(100)
    out = out.cpu().detach().numpy()
    for output in range(3):
        ax.plot(time, out[0, :, output], label=f"Channel {output}")
    ax.legend()
    ax.set_xlabel('t')
    ax.set_ylabel('Activation')
    ax.set_title('Output Activations (FC(3))')
    # fig.savefig(FIG_PATH + "\\neuron_activations\\" + f"{network_name}_output_activations.png")
# Out:
# Path already exists for FC_16_GRU_1layer_8hidden in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_8hidden in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_8hidden in task 0.1q. Assume the model is already trained.
# Using a scheduler
# Average geodesic distance: 6.540024757385254

# %% [markdown]
# # CNN_RNN work starts here
#
# ## Start by building a CNN from Config

# %%
CNN_config = train.build_config_cnn("CNN_FC_16_GRU_1layer_8hidden", "1.1", 0, 1, special_names="constant")
# Out:
# Path already exists for FC_16_GRU_1layer_8hidden in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_8hidden in task 0.1q. Assume the model is already trained.
# Path already exists for FC_16_GRU_1layer_8hidden in task 0.1q. Assume the model is already trained.
# Path already exists for CNN_FC_16_GRU_1layer_8hidden in task 1.1. Assume the model is already trained.
# Path already exists for CNN_FC_16_GRU_1layer_8hidden in task 1.1. Assume the model is already trained.
# Path already exists for CNN_FC_16_GRU_1layer_8hidden in task 1.1. Assume the model is already trained.

# %%
CNN_trainer = t.Trainer(CNN_config)
# Out:
# Using a scheduler

# %%
CNN_trainer.model.rnn_model.load_state_dict(trainer.model.rnn.state_dict())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 CNN_trainer.model.rnn_model.load_state_dict(trainer.model.rnn.state_dict())
#
# File ~\anaconda3\envs\mental-rotations\lib\site-packages\torch\nn\modules\module.py:2189, in Module.load_state_dict(self, state_dict, strict, assign)
#    2184         error_msgs.insert(
#    2185             0, 'Missing key(s) in state_dict: {}. '.format(
#    2186                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2188 if len(error_msgs) > 0:
# -> 2189     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2190                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2191 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for CustomRNN:
# 	Missing key(s) in state_dict: "rnn.weight_ih_l0", "rnn.weight_hh_l0", "rnn.bias_ih_l0", "rnn.bias_hh_l0", "fc.weight", "fc.bias".
# 	Unexpected key(s) in state_dict: "weight_ih_l0", "weight_hh_l0", "bias_ih_l0", "bias_hh_l0".

# %%
cnn_rnn_dict = CNN_trainer.model.rnn_model.state_dict()

# %%
import torch
import torchvision.models as models
from torchvision.models import ConvNeXt_Tiny_Weights

# %%
weights = ConvNeXt_Tiny_Weights.IMAGENET1K_V1
model = models.convnext_tiny(weights)
# Out:
# C:\Users\timmy\anaconda3\envs\mental-rotations\lib\site-packages\torchvision\models\_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# Downloading: "https://download.pytorch.org/models/convnext_tiny-983f1562.pth" to C:\Users\timmy/.cache\torch\hub\checkpoints\convnext_tiny-983f1562.pth
# 100%|██████████| 109M/109M [00:04<00:00, 28.1MB/s]

# %%
preprocess = weights.DEFAULT.transforms()
image = torch.rand(12, 3, 64, 64)
image_p = preprocess(image)

# %%
import torch.nn as nn
class ExperimentalModel(nn.Module): 
    def __init__(self, convnet, rnn_type = None): 
        super(ExperimentalModel, self).__init__() 
        if type(convnet) == str: 
            try: 
                weights = __import__("torchvision.models", fromlist = [convnet + "_Weights"])
                model = __import__("torchvision.models", fromlist = [convnet.lower()])
                self.conv = model(weights)
            except Exception as e: 
                raise NotImplementedError(f"{e}, wait for the full version!")
        elif isinstance(convnet, nn.Module): 
            self.conv = convnet
         
        self.conv_output_size = self.conv(torch.randn((1, 3, 64, 64))).shape[-3]
        
        # pool the last layer
        self.postprocess = nn.Sequential(
            nn.AdaptiveAvgPool2d(output_size=1),
            nn.Flatten(),
            nn.LayerNorm(self.conv_output_size), 
        )
        self.total_period = 100
        self.action_period = 50
        self.prep_period = self.total_period - self.action_period
        
        self.linear1_size = 64
        self.linear2_size = 32
        self.rnn_input_size = 16
        self.processing = nn.Sequential(
            nn.Linear(self.conv_output_size, self.linear1_size), 
            nn.ReLU(), 
            nn.Linear(self.linear1_size, self.linear2_size), 
            nn.ReLU(), 
            nn.Linear(self.linear2_size, self.rnn_input_size), 
            nn.ReLU()
        )
        if rnn_type is not None: 
            self.rnn = rnn_type
            self.hidden_size = self.rnn.hidden_size
        else: 
            self.rnn = nn.GRU(self.rnn_input_size, 8, 1, True) # BATCH FIRST
            self.hidden_size = 8
            
        self.output = nn.Linear(self.hidden_size, 3)
            
    def forward(self, x):
        """ Implements a simple forward loop.
        
        Args: x (batch_size, 3, dim1, dim2)
        """
        x = self.conv(x)
        x = self.postprocess(x)
        x = self.processing(x)
        batch_size, processed_size = x.shape
        x = torch.cat((x.unsqueeze(1).repeat(1, self.prep_period, 1), torch.zeros((batch_size, self.action_period, 
                                                                                   processed_size)
                                                                                  )), dim = 1)
        
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device).float()
        x, _ = self.rnn(x, h0)       
        x = self.output(x)
        print(x.shape)


dummy_input = torch.rand(5, 3, 128, 128)
experiment = ExperimentalModel(model.features) 
experiment(dummy_input)
# Out:
# torch.Size([5, 100, 3])

# %%
dummy_output = model.features(dummy_input)

# %%
nn.GroupNorm(num_groups = 1, num_channels = 768)
# Out:
# GroupNorm(1, 768, eps=1e-05, affine=True)

# %%
import torchvision
avgpool = nn.AdaptiveAvgPool2d(output_size=1)
layernorm = torchvision.models.convnext.LayerNorm2d(768)

# %%
dummy_output_avg = avgpool(dummy_output)

# %%
print(model)
# Out:
# ConvNeXt(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#       (1): LayerNorm2d((96,), eps=1e-06, elementwise_affine=True)
#     )
#     (1): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (1): Permute()
#           (2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=96, out_features=384, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=384, out_features=96, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (1): Permute()
#           (2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=96, out_features=384, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=384, out_features=96, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0058823529411764705, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (1): Permute()
#           (2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=96, out_features=384, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=384, out_features=96, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.011764705882352941, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): LayerNorm2d((96,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(96, 192, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (3): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.017647058823529415, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.023529411764705882, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.029411764705882353, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): LayerNorm2d((192,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(192, 384, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (5): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.03529411764705883, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0411764705882353, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.047058823529411764, mode=row)
#       )
#       (3): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.052941176470588235, mode=row)
#       )
#       (4): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.058823529411764705, mode=row)
#       )
#       (5): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.06470588235294118, mode=row)
#       )
#       (6): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.07058823529411766, mode=row)
#       )
#       (7): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.07647058823529412, mode=row)
#       )
#       (8): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0823529411764706, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): LayerNorm2d((384,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(384, 768, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (7): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.08823529411764706, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.09411764705882353, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): LayerNorm2d((768,), eps=1e-06, elementwise_affine=True)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=768, out_features=1000, bias=True)
#   )
# )

# %%
isinstance(model, nn.Module)
# Out:
# True

# %%
# Out:
# Sequential(
#   (0): Conv2dNormActivation(
#     (0): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#     (1): LayerNorm2d((96,), eps=1e-06, elementwise_affine=True)
#   )
#   (1): Sequential(
#     (0): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#         (1): Permute()
#         (2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=96, out_features=384, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=384, out_features=96, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#     )
#     (1): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#         (1): Permute()
#         (2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=96, out_features=384, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=384, out_features=96, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.0058823529411764705, mode=row)
#     )
#     (2): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#         (1): Permute()
#         (2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=96, out_features=384, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=384, out_features=96, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.011764705882352941, mode=row)
#     )
#   )
#   (2): Sequential(
#     (0): LayerNorm2d((96,), eps=1e-06, elementwise_affine=True)
#     (1): Conv2d(96, 192, kernel_size=(2, 2), stride=(2, 2))
#   )
#   (3): Sequential(
#     (0): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#         (1): Permute()
#         (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=192, out_features=768, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=768, out_features=192, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.017647058823529415, mode=row)
#     )
#     (1): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#         (1): Permute()
#         (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=192, out_features=768, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=768, out_features=192, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.023529411764705882, mode=row)
#     )
#     (2): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#         (1): Permute()
#         (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=192, out_features=768, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=768, out_features=192, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.029411764705882353, mode=row)
#     )
#   )
#   (4): Sequential(
#     (0): LayerNorm2d((192,), eps=1e-06, elementwise_affine=True)
#     (1): Conv2d(192, 384, kernel_size=(2, 2), stride=(2, 2))
#   )
#   (5): Sequential(
#     (0): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#         (1): Permute()
#         (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=384, out_features=1536, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=1536, out_features=384, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.03529411764705883, mode=row)
#     )
#     (1): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#         (1): Permute()
#         (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=384, out_features=1536, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=1536, out_features=384, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.0411764705882353, mode=row)
#     )
#     (2): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#         (1): Permute()
#         (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=384, out_features=1536, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=1536, out_features=384, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.047058823529411764, mode=row)
#     )
#     (3): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#         (1): Permute()
#         (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=384, out_features=1536, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=1536, out_features=384, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.052941176470588235, mode=row)
#     )
#     (4): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#         (1): Permute()
#         (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=384, out_features=1536, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=1536, out_features=384, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.058823529411764705, mode=row)
#     )
#     (5): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#         (1): Permute()
#         (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=384, out_features=1536, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=1536, out_features=384, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.06470588235294118, mode=row)
#     )
#     (6): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#         (1): Permute()
#         (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=384, out_features=1536, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=1536, out_features=384, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.07058823529411766, mode=row)
#     )
#     (7): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#         (1): Permute()
#         (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=384, out_features=1536, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=1536, out_features=384, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.07647058823529412, mode=row)
#     )
#     (8): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#         (1): Permute()
#         (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=384, out_features=1536, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=1536, out_features=384, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.0823529411764706, mode=row)
#     )
#   )
#   (6): Sequential(
#     (0): LayerNorm2d((384,), eps=1e-06, elementwise_affine=True)
#     (1): Conv2d(384, 768, kernel_size=(2, 2), stride=(2, 2))
#   )
#   (7): Sequential(
#     (0): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#         (1): Permute()
#         (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=768, out_features=3072, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=3072, out_features=768, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.08823529411764706, mode=row)
#     )
#     (1): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#         (1): Permute()
#         (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=768, out_features=3072, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=3072, out_features=768, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.09411764705882353, mode=row)
#     )
#     (2): CNBlock(
#       (block): Sequential(
#         (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#         (1): Permute()
#         (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (3): Linear(in_features=768, out_features=3072, bias=True)
#         (4): GELU(approximate='none')
#         (5): Linear(in_features=3072, out_features=768, bias=True)
#         (6): Permute()
#       )
#       (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#     )
#   )
# )
